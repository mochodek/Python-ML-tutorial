# %% [markdown]
# # Lesson 01 - Pandas basics

# %%
import pandas as pd
import numpy as np

pd.__version__
# Out:
# '0.22.0'

# %% [markdown]
# ## Load data and basic info
#
# Let's load a csv file and view it. We use pandas read_csv function to do that:
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_csv.html
#
# The function loads a csv file into an object of a DataFrame type.
#
# There are plenty of options to try out. Below, we parser dataes in two of the columns. Pandas uses the concept of index. You can use any column as an index. If you do not provide any, a sequential index is added.

# %%
bugs = pd.read_csv('./data/bugs_train.csv', parse_dates=['Opened', 'Changed'], index_col=None)

# %% [markdown]
# If you want to view your data frame you can use head and tail methods:

# %%
bugs.head(3)
# Out:
#   Component       Assignee    Status                                Summary  \
# 0     Debug        eclipse  VERIFIED     Icons needed for actions (1GI5UXW)
# 1     Debug  darin.eclipse  RESOLVED  README: Hit count not reset (1GET20Y)
# 2     Debug  darin.eclipse    CLOSED   Use styled text in console (1G9S1YF)
#
#                Opened             Changed Priority     Severity  Resolution
# 0 2001-10-10 22:14:41 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-10-10 22:14:42 2001-11-28 13:42:46       P3       normal  WORKSFORME
# 2 2001-10-10 22:14:43 2002-06-26 11:32:05       P3       normal     WONTFIX

# %%
bugs.head(5)
# Out:
#   Component       Assignee    Status  \
# 0     Debug        eclipse  VERIFIED
# 1     Debug  darin.eclipse  RESOLVED
# 2     Debug  darin.eclipse    CLOSED
# 3     Debug        eclipse  VERIFIED
# 4     Debug  darin.eclipse  RESOLVED
#
#                                              Summary              Opened  \
# 0                 Icons needed for actions (1GI5UXW) 2001-10-10 22:14:41
# 1              README: Hit count not reset (1GET20Y) 2001-10-10 22:14:42
# 2               Use styled text in console (1G9S1YF) 2001-10-10 22:14:43
# 3              StringBuffer representation (1GE3BFA) 2001-10-10 22:14:44
# 4  Feature: use #toString to display variable val... 2001-10-10 22:14:45
#
#               Changed Priority     Severity  Resolution
# 0 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-11-28 13:42:46       P3       normal  WORKSFORME
# 2 2002-06-26 11:32:05       P3       normal     WONTFIX
# 3 2014-12-02 06:37:26       P3       normal       FIXED
# 4 2001-10-17 10:17:47       P2  enhancement   DUPLICATE

# %%
bugs.tail(3)
# Out:
#       Component           Assignee    Status  \
# 44140      Text     jdt-text-inbox  RESOLVED
# 44141      Core  srikanth_sankaran  VERIFIED
# 44142     Debug    jdt-debug-inbox    CLOSED
#
#                                                  Summary              Opened  \
# 44140  Show selected element's javadoc in Declaration... 2012-08-29 11:04:01
# 44141           The method x is ambiguous for the type C 2012-08-29 12:11:27
# 44142  ClassCastException when evaluating "new Except... 2012-08-30 09:55:46
#
#                   Changed Priority     Severity  Resolution
# 44140 2012-08-29 11:11:13       P3  enhancement  WORKSFORME
# 44141 2012-10-10 11:52:12       P3        major   DUPLICATE
# 44142 2012-09-04 13:38:38       P3       normal   DUPLICATE

# %% [markdown]
# Sometimes, we want to see what are the data types of columns in our data frame.

# %%
bugs.dtypes
# Out:
# Component             object
# Assignee              object
# Status                object
# Summary               object
# Opened        datetime64[ns]
# Changed       datetime64[ns]
# Priority              object
# Severity              object
# Resolution            object
# dtype: object

# %% [markdown]
# We use shape property to see what are the dimensions of the data frame

# %%
bugs.shape
# Out:
# (44143, 9)

# %% [markdown]
# You can check the names of the columns by using the following code:

# %%
bugs.columns.get_values()
# Out:
# array(['Component', 'Assignee', 'Status', 'Summary', 'Opened', 'Changed',
#        'Priority', 'Severity', 'Resolution'], dtype=object)

# %% [markdown]
# ## Basic data manipulation

# %% [markdown]
# Selecting columns

# %%
bugs[['Component', 'Assignee']].head(2)
# Out:
#   Component       Assignee
# 0     Debug        eclipse
# 1     Debug  darin.eclipse

# %% [markdown]
# Accessing different cells by the loc method. You have to provide "labels" as coordinates to access a cell. If you use the default index, it is the labels. For columns this will be the names of columns:

# %%
# accessing by label - 3 is the index label in this case
bugs.loc[3, "Assignee"]
# Out:
# 'eclipse'

# %% [markdown]
# You can also provide a list of values to select subregions of the data frame.

# %%
bugs.loc[1:3, ["Assignee", "Status"]]
# Out:
#         Assignee    Status
# 1  darin.eclipse  RESOLVED
# 2  darin.eclipse    CLOSED
# 3        eclipse  VERIFIED

# %% [markdown]
# The ix methods gives you flexibility since you can access cells by label or position, however the method is now deprecated

# %%
bugs.ix[3, "Assignee"]
# Out:
# /Users/mochodek/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'eclipse'

# %%
bugs.ix[3, 1]
# Out:
# /Users/mochodek/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 'eclipse'

# %% [markdown]
# However, you can achieve the same behaviour using the standard loc and iloc methods

# %%
# using labels when you know the column number
bugs.loc[3, bugs.columns[1]]
# Out:
# 'eclipse'

# %% [markdown]
# We use the iloc method below. It works on indices instead of labels

# %%
bugs.iloc[bugs.index.get_loc(3), 1]
# Out:
# 'eclipse'

# %% [markdown]
# Remove rows/columns

# %%
# remove rows
bugs.drop([1,2], axis=0).head(4)
# Out:
#   Component       Assignee    Status  \
# 0     Debug        eclipse  VERIFIED
# 3     Debug        eclipse  VERIFIED
# 4     Debug  darin.eclipse  RESOLVED
# 5     Debug  darin.eclipse  RESOLVED
#
#                                              Summary              Opened  \
# 0                 Icons needed for actions (1GI5UXW) 2001-10-10 22:14:41
# 3              StringBuffer representation (1GE3BFA) 2001-10-10 22:14:44
# 4  Feature: use #toString to display variable val... 2001-10-10 22:14:45
# 5        Breakpoint in an invalid location (1G4F8P8) 2001-10-10 22:14:46
#
#               Changed Priority     Severity Resolution
# 0 2001-10-18 11:51:14       P1  enhancement      FIXED
# 3 2014-12-02 06:37:26       P3       normal      FIXED
# 4 2001-10-17 10:17:47       P2  enhancement  DUPLICATE
# 5 2002-09-10 17:00:45       P3  enhancement  DUPLICATE

# %%
#remove columns
bugs.drop(["Status","Assignee"], axis=1).head(4)
# Out:
#   Component                                Summary              Opened  \
# 0     Debug     Icons needed for actions (1GI5UXW) 2001-10-10 22:14:41
# 1     Debug  README: Hit count not reset (1GET20Y) 2001-10-10 22:14:42
# 2     Debug   Use styled text in console (1G9S1YF) 2001-10-10 22:14:43
# 3     Debug  StringBuffer representation (1GE3BFA) 2001-10-10 22:14:44
#
#               Changed Priority     Severity  Resolution
# 0 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-11-28 13:42:46       P3       normal  WORKSFORME
# 2 2002-06-26 11:32:05       P3       normal     WONTFIX
# 3 2014-12-02 06:37:26       P3       normal       FIXED

# %% [markdown]
# Rename

# %%
bugs.rename(columns={"Summary": "Info"}).head(2)
# Out:
#   Component       Assignee    Status                                   Info  \
# 0     Debug        eclipse  VERIFIED     Icons needed for actions (1GI5UXW)
# 1     Debug  darin.eclipse  RESOLVED  README: Hit count not reset (1GET20Y)
#
#                Opened             Changed Priority     Severity  Resolution
# 0 2001-10-10 22:14:41 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-10-10 22:14:42 2001-11-28 13:42:46       P3       normal  WORKSFORME

# %%
bugs.rename(columns=str.upper).head(2)
# Out:
#   COMPONENT       ASSIGNEE    STATUS                                SUMMARY  \
# 0     Debug        eclipse  VERIFIED     Icons needed for actions (1GI5UXW)
# 1     Debug  darin.eclipse  RESOLVED  README: Hit count not reset (1GET20Y)
#
#                OPENED             CHANGED PRIORITY     SEVERITY  RESOLUTION
# 0 2001-10-10 22:14:41 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-10-10 22:14:42 2001-11-28 13:42:46       P3       normal  WORKSFORME

# %% [markdown]
# We can also define our own function. Let's it add my_ as a suffix to the name of the column

# %%
def my_column(x):
    return "my_"+x
bugs.rename(columns=my_column).head(2)
# Out:
#   my_Component    my_Assignee my_Status  \
# 0        Debug        eclipse  VERIFIED
# 1        Debug  darin.eclipse  RESOLVED
#
#                               my_Summary           my_Opened  \
# 0     Icons needed for actions (1GI5UXW) 2001-10-10 22:14:41
# 1  README: Hit count not reset (1GET20Y) 2001-10-10 22:14:42
#
#            my_Changed my_Priority  my_Severity my_Resolution
# 0 2001-10-18 11:51:14          P1  enhancement         FIXED
# 1 2001-11-28 13:42:46          P3       normal    WORKSFORME

# %% [markdown]
# Changing type to category

# %%
bugs.Status.astype("category", categories=["VERIFIED", "RESOLVED", "CLOSED"], ordered=True).head()
# Out:
# 0    VERIFIED
# 1    RESOLVED
# 2      CLOSED
# 3    VERIFIED
# 4    RESOLVED
# Name: Status, dtype: category
# Categories (3, object): [VERIFIED < RESOLVED < CLOSED]

# %% [markdown]
# Filtering

# %%
bugs[bugs['Component'] == 'Debug' ].head(3)
# Out:
#   Component       Assignee    Status                                Summary  \
# 0     Debug        eclipse  VERIFIED     Icons needed for actions (1GI5UXW)
# 1     Debug  darin.eclipse  RESOLVED  README: Hit count not reset (1GET20Y)
# 2     Debug  darin.eclipse    CLOSED   Use styled text in console (1G9S1YF)
#
#                Opened             Changed Priority     Severity  Resolution
# 0 2001-10-10 22:14:41 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-10-10 22:14:42 2001-11-28 13:42:46       P3       normal  WORKSFORME
# 2 2001-10-10 22:14:43 2002-06-26 11:32:05       P3       normal     WONTFIX

# %%
bugs[ (bugs['Component'] == 'Debug') &  (bugs['Severity'] == 'normal') ].head(3)
# Out:
#   Component       Assignee    Status                                Summary  \
# 1     Debug  darin.eclipse  RESOLVED  README: Hit count not reset (1GET20Y)
# 2     Debug  darin.eclipse    CLOSED   Use styled text in console (1G9S1YF)
# 3     Debug        eclipse  VERIFIED  StringBuffer representation (1GE3BFA)
#
#                Opened             Changed Priority Severity  Resolution
# 1 2001-10-10 22:14:42 2001-11-28 13:42:46       P3   normal  WORKSFORME
# 2 2001-10-10 22:14:43 2002-06-26 11:32:05       P3   normal     WONTFIX
# 3 2001-10-10 22:14:44 2014-12-02 06:37:26       P3   normal       FIXED

# %%
bugs[ (bugs['Component'] == 'Debug') |  (bugs['Severity'] == 'normal') ].head(3)
# Out:
#   Component       Assignee    Status                                Summary  \
# 0     Debug        eclipse  VERIFIED     Icons needed for actions (1GI5UXW)
# 1     Debug  darin.eclipse  RESOLVED  README: Hit count not reset (1GET20Y)
# 2     Debug  darin.eclipse    CLOSED   Use styled text in console (1G9S1YF)
#
#                Opened             Changed Priority     Severity  Resolution
# 0 2001-10-10 22:14:41 2001-10-18 11:51:14       P1  enhancement       FIXED
# 1 2001-10-10 22:14:42 2001-11-28 13:42:46       P3       normal  WORKSFORME
# 2 2001-10-10 22:14:43 2002-06-26 11:32:05       P3       normal     WONTFIX

# %%
bugs[bugs['Opened'] > '2005'].head(2)
# Out:
#       Component        Assignee    Status  \
# 23571      Core     david_audel  RESOLVED
# 23572      Text  jdt-text-inbox  RESOLVED
#
#                                                  Summary              Opened  \
# 23571  content assist does not work past a constructo... 2005-01-01 01:07:21
# 23572                                look at the example 2005-01-01 09:59:55
#
#                   Changed Priority Severity Resolution
# 23571 2005-04-29 07:21:44       P3    major  DUPLICATE
# 23572 2005-01-03 05:03:31       P3   normal    INVALID

# %%
bugs[bugs['Priority'].isin(["P1", "P2"])].head(2)
# Out:
#   Component       Assignee    Status  \
# 0     Debug        eclipse  VERIFIED
# 4     Debug  darin.eclipse  RESOLVED
#
#                                              Summary              Opened  \
# 0                 Icons needed for actions (1GI5UXW) 2001-10-10 22:14:41
# 4  Feature: use #toString to display variable val... 2001-10-10 22:14:45
#
#               Changed Priority     Severity Resolution
# 0 2001-10-18 11:51:14       P1  enhancement      FIXED
# 4 2001-10-17 10:17:47       P2  enhancement  DUPLICATE

# %% [markdown]
# Adding a column (new values, based on existing columns)

# %%
bugs.assign(x=pd.Series(np.random.randn(bugs.shape[0])).values)
# Out:
#       Component            Assignee    Status  \
# 0         Debug             eclipse  VERIFIED
# 1         Debug       darin.eclipse  RESOLVED
# 2         Debug       darin.eclipse    CLOSED
# 3         Debug             eclipse  VERIFIED
# 4         Debug       darin.eclipse  RESOLVED
# 5         Debug       darin.eclipse  RESOLVED
# 6         Debug       darin.eclipse  VERIFIED
# 7         Debug       darin.eclipse  VERIFIED
# 8         Debug       darin.eclipse  RESOLVED
# 9         Debug     jdt-debug-inbox  RESOLVED
# 10        Debug       darin.eclipse  RESOLVED
# 11        Debug       darin.eclipse  RESOLVED
# 12        Debug     jdt-debug-inbox    CLOSED
# 13        Debug       darin.eclipse  VERIFIED
# 14        Debug       Darin_Swanson  VERIFIED
# 15        Debug     jdt-debug-inbox    CLOSED
# 16        Debug     jdt-debug-inbox    CLOSED
# 17        Debug       darin.eclipse  RESOLVED
# 18        Debug       darin.eclipse  VERIFIED
# 19        Debug       darin.eclipse  RESOLVED
# 20        Debug       darin.eclipse  RESOLVED
# 21        Debug     jdt-debug-inbox    CLOSED
# 22        Debug       darin.eclipse  VERIFIED
# 23        Debug     jdt-debug-inbox    CLOSED
# 24        Debug         jared_burns  VERIFIED
# 25        Debug       darin.eclipse  RESOLVED
# 26        Debug       darin.eclipse  RESOLVED
# 27        Debug       darin.eclipse  VERIFIED
# 28        Debug       Darin_Swanson  VERIFIED
# 29        Debug       darin.eclipse  RESOLVED
# ...         ...                 ...       ...
# 44113      Core      jdt-core-inbox    CLOSED
# 44114       APT       jdt-apt-inbox  RESOLVED
# 44115        UI  philippe.marschall  RESOLVED
# 44116      Core    stephan.herrmann  VERIFIED
# 44117        UI        jdt-ui-inbox    CLOSED
# 44118      Text          Lars.Vogel  RESOLVED
# 44119      Core   srikanth_sankaran  VERIFIED
# 44120      Core      jdt-core-inbox  VERIFIED
# 44121        UI          deepakazad  RESOLVED
# 44122      Core            jarthana  VERIFIED
# 44123        UI        jdt-ui-inbox  RESOLVED
# 44124      Core       markus_keller  VERIFIED
# 44125      Core    stephan.herrmann  VERIFIED
# 44126        UI          deepakazad  RESOLVED
# 44127        UI          deepakazad  RESOLVED
# 44128      Core            jarthana  RESOLVED
# 44129        UI        jdt-ui-inbox  RESOLVED
# 44130      Core            jarthana  VERIFIED
# 44131      Text      jdt-text-inbox    CLOSED
# 44132     Debug      Michael_Rennie  RESOLVED
# 44133      Core    stephan.herrmann  VERIFIED
# 44134      Text      jdt-text-inbox    CLOSED
# 44135      Core      jdt-core-inbox  VERIFIED
# 44136      Core    stephan.herrmann  VERIFIED
# 44137       Doc       daniel_megert  VERIFIED
# 44138      Text      jdt-text-inbox    CLOSED
# 44139        UI       markus_keller  RESOLVED
# 44140      Text      jdt-text-inbox  RESOLVED
# 44141      Core   srikanth_sankaran  VERIFIED
# 44142     Debug     jdt-debug-inbox    CLOSED
#
#                                                  Summary              Opened  \
# 0                     Icons needed for actions (1GI5UXW) 2001-10-10 22:14:41
# 1                  README: Hit count not reset (1GET20Y) 2001-10-10 22:14:42
# 2                   Use styled text in console (1G9S1YF) 2001-10-10 22:14:43
# 3                  StringBuffer representation (1GE3BFA) 2001-10-10 22:14:44
# 4      Feature: use #toString to display variable val... 2001-10-10 22:14:45
# 5            Breakpoint in an invalid location (1G4F8P8) 2001-10-10 22:14:46
# 6      Feature: Displaying Instruction pointer (1G3A7CG) 2001-10-10 22:14:47
# 7                  Feature: Locks and Monitors (1G3A7ZH) 2001-10-10 22:14:48
# 8      Snippet evaluation should support imports (1G4... 2001-10-10 22:14:49
# 9      [scrapbook] Snippet editor color snippet outpu... 2001-10-10 22:14:50
# 10       snippets: can start SWT program twice (1G47CME) 2001-10-10 22:14:51
# 11     On exit, should allow user to continue executi... 2001-10-10 22:14:52
# 12     UI - Inconsistent GUI behavior in "Breakpoints... 2001-10-10 22:14:53
# 13     Feature: navigate from console output to resou... 2001-10-10 22:14:54
# 14               UI - Right click "Run" button (1G5T50T) 2001-10-10 22:14:55
# 15                      [variables] snapshot and compare 2001-10-10 22:14:57
# 16                DCR: support debug on demand (1G71C81) 2001-10-10 22:14:58
# 17     Performance: Optimizations to handle really bi... 2001-10-10 22:14:59
# 18     classFilePattern breakpoint attribute optimiza... 2001-10-10 22:15:00
# 19     Watch List - expressions and adding in advance... 2001-10-10 22:15:01
# 20            Internationalization of integers (1G8U8KN) 2001-10-10 22:15:02
# 21     Feature: Drag and Drop to the inspector (1G8FNNV) 2001-10-10 22:15:03
# 22                               UI extensions (1G9YWCG) 2001-10-10 22:15:04
# 23     Object.wait() not selected when suspending thr... 2001-10-10 22:15:05
# 24     folders included in 'choose package' dialog (1... 2001-10-10 22:15:06
# 25         Unable to terminate thread until... (1GAJOUQ) 2001-10-10 22:15:07
# 26                  Feature: Breakpoint groups (1GANCOZ) 2001-10-10 22:15:08
# 27                    Remote Evaluation (AST evaluation) 2001-10-10 22:15:09
# 28                    duplicate variable names (1GB7V3E) 2001-10-10 22:15:10
# 29                     Extensible launch modes (1GBEQYO) 2001-10-10 22:15:11
# ...                                                  ...                 ...
# 44113  Change Method Signature refactoring failed wit... 2012-08-17 14:29:01
# 44114            Returning date is accepting wrong value 2012-08-18 01:37:18
# 44115  [type wizards] generate main method stub ignor... 2012-08-18 10:39:53
# 44116  Unreachable catch block...exception is never t... 2012-08-20 10:32:13
# 44117  [pull up] Pull up refactoring loses Javadoc wh... 2012-08-21 04:42:12
# 44118          [templates] template to define a variable 2012-08-22 11:13:05
# 44119  NPE in org.eclipse.jdt.internal.compiler.probl... 2012-08-23 04:11:06
# 44120                NPE in "org.eclipse.core.resources" 2012-08-23 14:27:09
# 44121  [quick fix] Add unimplemented methods quickfix... 2012-08-23 23:15:32
# 44122  Cannot resolve import for generated class IF p... 2012-08-24 04:58:44
# 44123  Eclipse Classic 4.2.0 no response with PermGen... 2012-08-24 20:39:40
# 44124  Add unimplemented methods fails with exception... 2012-08-24 21:55:37
# 44125  [compiler][null] better merging of null info d... 2012-08-25 13:48:07
# 44126  [quick assist] invert if statement ignores ope... 2012-08-27 02:44:11
# 44127  [inline] inline logical or in and expression g... 2012-08-27 03:08:43
# 44128  [1.8][compiler] Type annotations on a wildcard... 2012-08-27 05:28:55
# 44129       Import Projects does not save Root Directory 2012-08-27 06:03:24
# 44130  MethodBinding.getJavaElement() returns non-exi... 2012-08-27 14:44:29
# 44131  [content assist] Content Assist autocomplete f... 2012-08-27 14:57:18
# 44132  JDI ArrayIndexOutOfBoundsException when debugg... 2012-08-28 04:54:08
# 44133             final String not detected as Dead Code 2012-08-28 06:13:20
# 44134  [navigation] "Open Implementation" not clickab... 2012-08-28 09:18:49
# 44135                     Very long delay in "Open Type" 2012-08-28 17:57:30
# 44136  [compiler][null] inheritance of null annotatio... 2012-08-28 19:11:37
# 44137  Typo on jdt.doc.user\reference\preferences\jav... 2012-08-29 03:06:46
# 44138  corrupted editor contents after save actions a... 2012-08-29 05:15:40
# 44139  [type wizards] Main Method Stub Check Box in t... 2012-08-29 10:15:12
# 44140  Show selected element's javadoc in Declaration... 2012-08-29 11:04:01
# 44141           The method x is ambiguous for the type C 2012-08-29 12:11:27
# 44142  ClassCastException when evaluating "new Except... 2012-08-30 09:55:46
#
#                   Changed Priority     Severity   Resolution         x
# 0     2001-10-18 11:51:14       P1  enhancement        FIXED -0.682905
# 1     2001-11-28 13:42:46       P3       normal   WORKSFORME -0.431203
# 2     2002-06-26 11:32:05       P3       normal      WONTFIX -0.411560
# 3     2014-12-02 06:37:26       P3       normal        FIXED -0.230694
# 4     2001-10-17 10:17:47       P2  enhancement    DUPLICATE -1.308299
# 5     2002-09-10 17:00:45       P3  enhancement    DUPLICATE -0.505187
# 6     2002-11-22 09:33:05       P2  enhancement        FIXED  1.343028
# 7     2002-09-30 12:24:15       P2  enhancement        FIXED  0.138182
# 8     2002-03-18 15:23:50       P3       normal    DUPLICATE  0.766269
# 9     2009-08-30 02:22:18       P3  enhancement      WONTFIX -1.012810
# 10    2002-02-26 14:19:30       P3       normal      WONTFIX -0.817646
# 11    2003-05-06 22:35:44       P3  enhancement      WONTFIX  1.347569
# 12    2009-08-30 02:18:21       P3  enhancement      WONTFIX -0.243364
# 13    2001-10-18 11:09:09       P1  enhancement        FIXED  1.227577
# 14    2001-12-13 18:52:25       P2  enhancement        FIXED -0.727091
# 15    2009-08-30 02:14:35       P4  enhancement      WONTFIX -0.161257
# 16    2009-08-30 02:18:51       P4  enhancement      WONTFIX -0.059669
# 17    2002-06-25 14:37:10       P3  enhancement    DUPLICATE  0.184359
# 18    2001-10-17 10:30:32       P3       normal        FIXED -0.371914
# 19    2002-01-15 12:29:33       P3  enhancement    DUPLICATE -1.758544
# 20    2002-02-01 11:56:22       P3       normal      WONTFIX  0.798693
# 21    2009-08-30 02:43:14       P3  enhancement      WONTFIX -0.251571
# 22    2002-06-26 11:11:09       P3  enhancement        FIXED  2.205160
# 23    2009-08-30 02:38:53       P4  enhancement      WONTFIX -0.832892
# 24    2002-04-08 09:44:24       P3        minor        FIXED -0.644214
# 25    2002-01-16 12:52:45       P3  enhancement    DUPLICATE -0.633264
# 26    2003-10-30 10:13:13       P3  enhancement    DUPLICATE -0.091949
# 27    2002-04-01 09:49:34       P1       normal        FIXED -1.125258
# 28    2003-10-02 21:37:22       P3  enhancement        FIXED -2.730381
# 29    2001-12-11 13:20:29       P2  enhancement      WONTFIX -0.409078
# ...                   ...      ...          ...          ...       ...
# 44113 2013-01-08 04:26:34       P3       normal    DUPLICATE  0.580344
# 44114 2012-08-18 19:35:52       P3        major      INVALID  0.347018
# 44115 2012-08-24 03:31:54       P3       normal        FIXED  0.649313
# 44116 2012-09-17 23:19:22       P3        major        FIXED  1.451049
# 44117 2012-08-21 23:39:39       P3       normal    DUPLICATE  2.887795
# 44118 2015-04-21 11:36:35       P3  enhancement      WONTFIX -0.978269
# 44119 2012-08-30 01:56:41       P3       normal    DUPLICATE  0.429570
# 44120 2012-09-17 23:26:31       P3       normal    DUPLICATE  1.395875
# 44121 2013-06-27 01:39:15       P3       normal        FIXED  1.409685
# 44122 2017-03-22 06:45:39       P3        major        FIXED -0.232642
# 44123 2012-09-18 03:26:46       P3      blocker   WORKSFORME  1.804902
# 44124 2013-06-06 10:27:53       P3       normal        FIXED  0.806547
# 44125 2014-12-09 10:26:05       P3  enhancement    DUPLICATE  0.528391
# 44126 2012-10-19 05:23:26       P3       normal        FIXED  0.513695
# 44127 2012-10-18 01:10:06       P3       normal        FIXED  0.966851
# 44128 2012-10-01 05:45:24       P3       normal        FIXED -0.011322
# 44129 2012-08-27 06:16:26       P3       normal  NOT_ECLIPSE -0.391885
# 44130 2012-09-18 02:45:10       P3        major        FIXED  0.915531
# 44131 2013-08-02 05:29:19       P3  enhancement    DUPLICATE  0.550164
# 44132 2012-10-01 15:19:46       P3       normal        FIXED -0.622894
# 44133 2012-09-17 23:36:27       P3       normal    DUPLICATE  0.168023
# 44134 2012-08-28 09:21:18       P3       normal    DUPLICATE -1.101650
# 44135 2013-02-04 11:05:36       P3        major   WORKSFORME -0.371155
# 44136 2012-12-12 10:11:04       P3  enhancement        FIXED  0.155684
# 44137 2012-08-30 03:33:33       P3       normal        FIXED  0.136125
# 44138 2012-08-30 07:23:32       P3       normal    DUPLICATE -1.109832
# 44139 2012-09-03 14:10:40       P3        minor        FIXED -1.269364
# 44140 2012-08-29 11:11:13       P3  enhancement   WORKSFORME  1.451627
# 44141 2012-10-10 11:52:12       P3        major    DUPLICATE  0.585739
# 44142 2012-09-04 13:38:38       P3       normal    DUPLICATE  0.019416
#
# [44143 rows x 10 columns]

# %% [markdown]
# Merge by row

# %%
pd.concat([bugs, bugs], axis=0).head(1)
# Out:
#   Component Assignee    Status                             Summary  \
# 0     Debug  eclipse  VERIFIED  Icons needed for actions (1GI5UXW)
#
#                Opened             Changed Priority     Severity Resolution
# 0 2001-10-10 22:14:41 2001-10-18 11:51:14       P1  enhancement      FIXED

# %% [markdown]
# Merge by column

# %%
pd.concat([bugs, bugs], axis=1).head(1)

# %% [markdown]
# ## Tasks

# %% [markdown]
# Task 1. Display last ten rows of the bugs data frame

# %% [markdown]
# Task 2. Create a new data frame by selected Opened, Changed, and Prority columns from bugs

# %% [markdown]
# Task 3. Select 20 row and columns Opened, Changed, Priority of bugs

# %% [markdown]
# Task 4. Remove the column Summary from the bugs

# %% [markdown]
# Task 5. Select rows for which Assignee is eclipse
